# %% [markdown]
# # Problem Set 3
# ### Question 3

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
def calcEnd(line,sizeReducer,angle,ax): # given line= (startingLength,init_x,init_y)  .6 , ax
    l,x,y = line
    l=l*sizeReducer
    x2 = x + (l) * math.cos(math.radians(angle))
    y2 = y + (l) * math.sin(math.radians(angle))
    #print(x,y)
    #print(x2,y2)
    ax.plot([x,x2],[y,y2])
    return x2,y2,l,angle+90,ax
def calcHelper(x,y,l,startingAngleL,startingAngleR,ax,ct):
    xl,yl,ll,angleL=x,y,l,startingAngleL
    xr,yr,lr,angleR =x,y,l,startingAngleR
    linel= (ll,xl,yl)
    liner= (lr,xr,yr)
    xl,yl,ll,angleL,ax = calcEnd(linel,.6,angleL,ax)
    xr,yr,lr,angleR,ax = calcEnd(liner,.6,angleR,ax)
    
    if(ll<=1):
        return 1
    calcHelper(xl,yl,ll,angleL,angleR,ax,ct)
    calcHelper(xr,yr,lr,angleL,angleR,ax,ct)
    
def segment(n):
    fig, ax = plt.subplots()
    #starting conditions
    startingLength= 1500
    startingAngleL= 0
    startingAngleR= 180
    init_x=0
    init_y=0
    
    #line
    #line= (startingLength,init_x,init_y)
    ax.plot([init_x,0],[init_y,1500])
    #x,y,l,angle,ax = calcEnd(line,1,180,ax)
    x=0
    y=1500
    l= startingLength
    xl,yl,ll,angleL=x,y,l,startingAngleL
    xr,yr,lr,angleR =x,y,l,startingAngleR
    ct=0
    
    ct = calcHelper(x,y,l,startingAngleL,startingAngleR,ax,ct)
    #for i in range(n):
    #draw two lines one for right and one for left that are .6 the last segment length
    """
    xl,yl,ll,angleL=x,y,l,startingAngleL
    xr,yr,lr,angleR =x,y,l,startingAngleR
    linel= (ll,xl,yl)
    liner= (lr,xr,yr)
    xl,yl,ll,angleL,ax = calcEnd(linel,.6,angleL,ax)
    xr,yr,lr,angleR,ax = calcEnd(liner,.6,angleR,ax)"""
    plt.xlim(-2000,2000)
    plt.ylim(-100,3000)
    plt.show()
    
segment(1)

# %%
def calcEnd(line,sizeReducer,angle,ax): # given line= (startingLength,init_x,init_y)  .6 , ax
    l,x,y = line
    l=l*sizeReducer
    x2 = x + (l) * math.cos(math.radians(angle))
    y2 = y + (l) * math.sin(math.radians(angle))
    #print(x,y)
    #print(x2,y2)
    ax.plot([x,x2],[y,y2])
    return x2,y2,l,angle+90,ax
def calcHelper(x,y,l,startingAngleL,startingAngleR,ax,ct):
    xl,yl,ll,angleL=x,y,l,startingAngleL
    xr,yr,lr,angleR =x,y,l,startingAngleR
    linel= (ll,xl,yl)
    liner= (lr,xr,yr)
    xl,yl,ll,angleL,ax = calcEnd(linel,.7,angleL,ax)
    xr,yr,lr,angleR,ax = calcEnd(liner,.7,angleR,ax)
    
    if(ll<=15):
        return 1
    calcHelper(xl,yl,ll,angleL,angleR,ax,ct)
    calcHelper(xr,yr,lr,angleL,angleR,ax,ct)
    
def segment(n):
    fig, ax = plt.subplots()
    #starting conditions
    startingLength= 1500
    startingAngleL= 0
    startingAngleR= 180
    init_x=0
    init_y=0
    
    #line
    #line= (startingLength,init_x,init_y)
    ax.plot([init_x,0],[init_y,1500])
    #x,y,l,angle,ax = calcEnd(line,1,180,ax)
    x=0
    y=1500
    l= startingLength
    xl,yl,ll,angleL=x,y,l,startingAngleL
    xr,yr,lr,angleR =x,y,l,startingAngleR
    ct=0
    
    ct = calcHelper(x,y,l,startingAngleL,startingAngleR,ax,ct)
    #for i in range(n):
    #draw two lines one for right and one for left that are .6 the last segment length
    """
    xl,yl,ll,angleL=x,y,l,startingAngleL
    xr,yr,lr,angleR =x,y,l,startingAngleR
    linel= (ll,xl,yl)
    liner= (lr,xr,yr)
    xl,yl,ll,angleL,ax = calcEnd(linel,.6,angleL,ax)
    xr,yr,lr,angleR,ax = calcEnd(liner,.6,angleR,ax)"""
    plt.xlim(-2000,2000)
    plt.ylim(-100,3000)
    plt.show()
    
segment(1)

# %% [markdown]
# Adjusting for different segment ratios and angles between left and right branches

# %%
def calcEnd(line,sizeReducer,angle,ax,angleAdjustment): # given line= (startingLength,init_x,init_y)  .6 , ax
    l,x,y = line
    l=l*sizeReducer
    x2 = x + (l) * math.cos(math.radians(angle))
    y2 = y + (l) * math.sin(math.radians(angle))
    #print(x,y)
    #print(x2,y2)
    ax.plot([x,x2],[y,y2])
    return x2,y2,l,angle+angleAdjustment,ax
def calcHelper(x,y,l,startingAngleL,startingAngleR,ax,ct):
    xl,yl,ll,angleL=x,y,l,startingAngleL
    xr,yr,lr,angleR =x,y,l,startingAngleR
    linel= (ll,xl,yl)
    liner= (lr,xr,yr)
    xl,yl,ll,angleL,ax = calcEnd(linel,.70,angleL,ax,120)
    xr,yr,lr,angleR,ax = calcEnd(liner,.65,angleR,ax,40)
    
    if(ll<=15):
        return 1
    calcHelper(xl,yl,ll,angleL,angleR,ax,ct)
    calcHelper(xr,yr,lr,angleL,angleR,ax,ct)
    
def segment(n):
    fig, ax = plt.subplots()
    #starting conditions
    startingLength= 1500
    startingAngleL= 120
    startingAngleR= 40
    init_x=0
    init_y=0
    
    #line
    #line= (startingLength,init_x,init_y)
    ax.plot([init_x,0],[init_y,1500])
    #x,y,l,angle,ax = calcEnd(line,1,180,ax)
    x=0
    y=1500
    l= startingLength
    xl,yl,ll,angleL=x,y,l,startingAngleL
    xr,yr,lr,angleR =x,y,l,startingAngleR
    ct=0
    
    ct = calcHelper(x,y,l,startingAngleL,startingAngleR,ax,ct)
    #for i in range(n):
    #draw two lines one for right and one for left that are .6 the last segment length
    """
    xl,yl,ll,angleL=x,y,l,startingAngleL
    xr,yr,lr,angleR =x,y,l,startingAngleR
    linel= (ll,xl,yl)
    liner= (lr,xr,yr)
    xl,yl,ll,angleL,ax = calcEnd(linel,.6,angleL,ax)
    xr,yr,lr,angleR,ax = calcEnd(liner,.6,angleR,ax)"""
    plt.xlim(-2000,2000)
    plt.ylim(-100,3000)
    plt.show()
    
segment(1)
